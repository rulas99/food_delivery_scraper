# %%
import pandas as pd
from glob import glob
from tqdm import tqdm

# %%
uber_files = glob('./results/uber/*.json')
uber_data = pd.concat([pd.read_json(f, lines=False) for f in tqdm(uber_files)],
                      ignore_index=True)

rappi_files = glob('./results/rappi/*.json')
rappi_data = pd.concat([pd.read_json(f, lines=False) for f in tqdm(rappi_files)],
                       ignore_index=True)
# Out:
# 100%|██████████| 1110/1110 [00:01<00:00, 759.88it/s]
# 100%|██████████| 1078/1078 [00:01<00:00, 633.57it/s]

# %%
complete_data = pd.concat([uber_data, rappi_data], ignore_index=True)
complete_data.to_csv('./results/complete_data.csv', index=False)
complete_data
# Out:
#                                                     text  \
# 0      Froyy's Taco\nFroyy's Taco\n4.4\n(6,000+)\n • ...
# 1      Taquerías Los 3 Chinelos\nTaquerías Los 3 Chin...
# 2      Taquería Habannas Prime\nTaquería Habannas Pri...
# 3      Taco Express\nTaco Express\n4.5\n(4,000+)\n • ...
# 4      Taqueria 3 Hermanos\nTaqueria 3 Hermanos\n4.6\...
# ...                                                  ...
# 61050                     Pane Envía\n46 min\n·\n$ 18.90
# 61051  La Chinampa Auténtica Taquería\n36 min\n·\n$ 2...
# 61052                Cochinita Power\n41 min\n·\n$ 24.90
# 61053          Taqueria El Tizoncito\n31 min\n·\n$ 20.90
# 61054              Pinche Gringo BBQ\n46 min\n·\n$ 20.90
#
#                                                     href      cate_source  \
# 0      https://www.ubereats.com/mx/store/froyys-taco-...  populares_cerca
# 1      https://www.ubereats.com/mx/store/taquerias-lo...  populares_cerca
# 2      https://www.ubereats.com/mx/store/taqueria-hab...  populares_cerca
# 3      https://www.ubereats.com/mx/store/taco-express...  populares_cerca
# 4      https://www.ubereats.com/mx/store/taqueria-3-h...  populares_cerca
# ...                                                  ...              ...
# 61050  https://www.rappi.com.mx/restaurantes/10001237...  populares_cerca
# 61051  https://www.rappi.com.mx/restaurantes/90000025...  populares_cerca
# 61052  https://www.rappi.com.mx/restaurantes/90000124...  populares_cerca
# 61053  https://www.rappi.com.mx/restaurantes/90000127...  populares_cerca
# 61054  https://www.rappi.com.mx/restaurantes/90000147...  populares_cerca
#
#                current_address  \
# 0      14600, Ciudad de México
# 1      14600, Ciudad de México
# 2      14600, Ciudad de México
# 3      14600, Ciudad de México
# 4      14600, Ciudad de México
# ...                        ...
# 61050  06020, Ciudad de México
# 61051  06020, Ciudad de México
# 61052  06020, Ciudad de México
# 61053  06020, Ciudad de México
# 61054  06020, Ciudad de México
#
#                                            final_address  platform
# 0      Location marker\n14600\nValle Escondido Ciudad...  ubereats
# 1      Location marker\n14600\nValle Escondido Ciudad...  ubereats
# 2      Location marker\n14600\nValle Escondido Ciudad...  ubereats
# 3      Location marker\n14600\nValle Escondido Ciudad...  ubereats
# 4      Location marker\n14600\nValle Escondido Ciudad...  ubereats
# ...                                                  ...       ...
# 61050  Centro Cultural de España en México, Calle Rep...     rappi
# 61051  Centro Cultural de España en México, Calle Rep...     rappi
# 61052  Centro Cultural de España en México, Calle Rep...     rappi
# 61053  Centro Cultural de España en México, Calle Rep...     rappi
# 61054  Centro Cultural de España en México, Calle Rep...     rappi
#
# [61055 rows x 6 columns]

# %%
complete_data.current_address.nunique()
# Out:
# 1110

# %%
complete_data.platform.value_counts(normalize=True)
# Out:
# platform
# ubereats    0.64889
# rappi       0.35111
# Name: proportion, dtype: float64

# %%
complete_data.href.nunique()
# Out:
# 3205

# %%
complete_data.href.value_counts(normalize=False).iloc[:10]
# Out:
# href
# https://www.rappi.com.mx/restaurantes/10000947-la-raclette                              281
# https://www.rappi.com.mx/restaurantes/10000872-chilaquil-del-valle                      273
# https://www.rappi.com.mx/restaurantes/10001224-los-panchos-tolstoi                      256
# https://www.rappi.com.mx/restaurantes/300000125-barbacoa-de-santiago                    229
# https://www.ubereats.com/mx/store/taqueria-el-rinconcito-mixe/OmBvp2ZVQ86XI1iio9DJiA    208
# https://www.ubereats.com/mx/store/quesadillas-mari-fortuna/QaQcuFWSXpqm2xi-t4iiZw       203
# https://www.ubereats.com/mx/store/taqueria-los-tioss/6K-bmxXCSb--sIyUx_7DuQ             196
# https://www.rappi.com.mx/restaurantes/10000876-macelleria                               191
# https://www.ubereats.com/mx/store/estrella-de-jalisco-2/oV46PpcyRNu_DyW_98kpng          167
# https://www.ubereats.com/mx/store/santas-alitas-coapa/a4loZ2AOUh2J34BHQv8pbQ            166
# Name: count, dtype: int64
